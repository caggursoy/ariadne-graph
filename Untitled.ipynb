# %%
# Prerequisites, just run this
import networkx as nx
import pandas as pd
import json
from ipycytoscape import *
df = pd.read_csv('data_materialcheck.csv', sep=';')

# %%
# Also this
df = df.fillna('')
df
# Out:
#     id   type                         label      shape       fillcolor  \
# 0    1  lower                 Project Start  rectangle          Purple
# 1    2  lower               Type of Project    diamond         Thistle
# 2    3  lower                 Type of Study    diamond         Thistle
# 3    4  lower             Data Availability    diamond         Thistle
# 4    5  lower               Data Simulation    diamond         Thistle
# 5    6  lower             Experiment Design  rectangle          Purple
# 6    7  lower               Data Collection  rectangle          Purple
# 7    8  lower               Data Validation  rectangle          Purple
# 8    9  lower                 Data Analysis  rectangle          Purple
# 9   10  lower                       Writing  rectangle          Purple
# 10  11  lower                 Dissemination  rectangle          Purple
# 11  12  lower                   Project End  rectangle          Purple
# 12  14  lower       Type of Preregistration    diamond           Cyan4
# 13  15  lower  Preregistration Metaanalysis    diamond           Cyan4
# 14  16  lower              Design Framework    diamond           Cyan4
# 15  17  lower                   Sample Size    diamond           Cyan4
# 16  18  lower                       Stimuli    diamond           Cyan4
# 17  19  lower                     Open Code    diamond           Cyan4
# 18  20  lower                Open Materials    diamond           Cyan4
# 19  21  lower                     Open Data    diamond           Cyan4
# 20  22  lower                  Presentation    diamond           Cyan4
# 21  23  lower       Type of Preregistration    diamond           Cyan4
# 22  24  lower               Preregistration    diamond      OliveDrab3
# 23  25  lower     Preregistration Framework    diamond      SteelBlue1
# 24  26  lower             Registered Report    diamond      OliveDrab3
# 25  27  lower                 OSF Templates     circle  PaleVioletRed3
# 26  28  lower         AsPredicted Templates     circle  PaleVioletRed3
# 27  29  lower   Registered Report Framework    diamond      SteelBlue1
# 28  30  lower                       Journal     circle  PaleVioletRed3
#
#    fontcolor  rank               subgraph              connection_from  \
# 0      white     1                initial                Project Start
# 1      white     1                initial              Type of Project
# 2      white     1                initial                Type of Study
# 3      white     1                initial            Data Availability
# 4      white     1                initial              Data Simulation
# 5      white     1                initial            Experiment Design
# 6      white     1                initial              Data Collection
# 7      white     1                initial              Data Validation
# 8      white     1                initial                Data Analysis
# 9      white     1                initial                      Writing
# 10     white     1                initial                Dissemination
# 11     white     1                initial
# 12     white     2          TypeofProject              Type of Project
# 13     white     2            TypeofStudy                Type of Study
# 14     white     2      Experiment Design            Experiment Design
# 15     white     2      Experiment Design            Experiment Design
# 16     white     2      Experiment Design            Experiment Design
# 17     white     2          Dissemination                Dissemination
# 18     white     2          Dissemination                Dissemination
# 19     white     2          Dissemination                Dissemination
# 20     white     2          Dissemination                Dissemination
# 21     white     2  TypeofPreregistration      Type of Preregistration
# 22     black     3  TypeofPreregistration              Preregistration
# 23     black     4  TypeofPreregistration      Type of Preregistration
# 24     black     3  TypeofPreregistration            Registered Report
# 25     black     5  TypeofPreregistration    Preregistration Framework
# 26     black     5  TypeofPreregistration    Preregistration Framework
# 27     black     4  TypeofPreregistration  Registered Report Framework
# 28     black     5  TypeofPreregistration
#
#                    connection_to              edgeLabel
# 0                Type of Project
# 1                  Type of Study  Continue after choice
# 2              Data Availability               Empircal
# 3                Data Simulation
# 4              Experiment Design
# 5                Data Collection
# 6                Data Validation
# 7                  Data Analysis
# 8                        Writing
# 9                  Dissemination
# 10                   Project End
# 11
# 12       Type of Preregistration
# 13  Preregistration Metaanalysis
# 14              Design Framework
# 15                   Sample Size
# 16                       Stimuli
# 17                     Open Code
# 18                Open Materials
# 19                     Open Data
# 20                  Presentation
# 21               Preregistration
# 22     Preregistration Framework
# 23             Registered Report
# 24   Registered Report Framework
# 25                 OSF Templates
# 26         AsPredicted Templates
# 27                       Journal
# 28

# %%
# Import stuff to dynamically update the graph
from ipywidgets import Output
from IPython.display import display

# instantiate an jupyternotebook output
out = Output()
# style
fin_style = []
# define a function that draws the network wrt a selected node
def draw_net(node_filter): 
    base_graph = nx.Graph() # reset the network obj
    for index, row in df.iterrows(): # iterate the dataframe
        if row['subgraph'] == node_filter.replace(' ',''): # if the clicked node has a subgraph
            base_graph.add_node(row['connection_to']) # add node
            base_graph.add_node(row['connection_from']) # add node
            base_graph.add_edge(row['connection_to'], row['connection_from']) # now connect the nodes
            rank = row['rank'] # also use rank as output
            subgraph = row['subgraph'] # also use subgraph as output
        elif row['label'] == node_filter: # if the clicked node does not have a subgraph, but it is alone
            base_graph.add_node(row['label']) # just draw the node on its own
            rank = row['rank'] # also use rank as output
            subgraph = row['subgraph'] # also use subgraph as output
    return [base_graph,rank,subgraph] # return the drawn graph
# define a function that logs mouse clicks
def log_clicks(node):
    # style
    fin_style = []
    with out: # while the graph is drawn
        [net,rank,subgraph] = draw_net(node['data']['id']) # draw the network
        cytoscapeobj.graph.clear() # reset cytoscape object
        cytoscapeobj.graph.add_graph_from_networkx(net, directed=True) # now convert the network to a cytoscape object
        cytoscapeobj.set_layout(name = 'dagre')  # it is hierarchical, so show it like that!
        for node in net.nodes: # now iterate the nodes
            shape = df[df.eval("(label == \""+node+"\") & ("+"subgraph == \""+subgraph+"\") & (rank == "+str(rank)+")")]['shape'].values # get the shape by filtering the dataframe
            if len(shape) == 0: # if not found, i.e. 0th level node
                shape = ['rectangle'] # draw as rectangle
            node_dict = {'selector': f'node[id = \"{node}\"]'} # get node id in cyto logic
            style_dict = {"style": {'font-family': 'helvetica','font-size': '20px','label': node, 'shape':shape[0]}} # put node id and shape in cyto logic
            node_dict.update(style_dict) # update dict
            fin_style.append(node_dict) # append to style list
        cytoscapeobj.set_style(fin_style) # now set the final style
# just initialise the 0th level graph
def init_graph():
    base_graph = nx.Graph() # reset the network obj
    for index, row in df.iterrows(): # iterate the dataframe
        if row['subgraph'] == 'initial' and row['rank'] == 1: # only draw the initial and 0th level nodes
        #base_graph.add_node(row['connection_to'])
        #base_graph.add_node(row['connection_from'])
            base_graph.add_edge(row['connection_to'], row['connection_from']) # add the edges, nodes should be added automatically
    cytoscapeobj.graph.clear() # reset cytoscape object
    cytoscapeobj.graph.add_graph_from_networkx(base_graph, directed=True) # now convert the network to a cytoscape object
    cytoscapeobj.set_layout(name = 'circle') # show it in a circular fashion
    cytoscapeobj.set_style(my_style) # set the style
# reset the graph
def res_graph(node):
    with out: # reset the DRAWN graph
        base_graph = nx.Graph() # reset the network obj
        for index, row in df.iterrows(): # iterate the dataframe
            if row['subgraph'] == 'initial' and row['rank'] == 1: # only draw the initial and 0th level nodes 
            #base_graph.add_node(row['connection_to'])
            #base_graph.add_node(row['connection_from'])
                base_graph.add_edge(row['connection_to'], row['connection_from']) # add the edges, nodes should be added automatically
        cytoscapeobj.graph.clear() # reset cytoscape object
        cytoscapeobj.graph.add_graph_from_networkx(base_graph, directed=True) # now convert the network to a cytoscape object
        cytoscapeobj.set_layout(name = 'circle') # show it in a circular fashion
        cytoscapeobj.set_style(my_style) # set the style
    
cytoscapeobj = CytoscapeWidget() # ok now create the cytoscape object
my_style = [ # a variable for our initial style
    {'selector': 'node','style': {
        'font-family': 'helvetica',
        'font-size': '20px',
        'label': 'data(id)', 'shape':'rectangle'}},
    ]
init_graph() # init the network graph
#cytoscapeobj.set_style(my_style) # set the style
#
cytoscapeobj.on('node', 'click', log_clicks) # dynamically listen to left clicks
cytoscapeobj.on('node', 'cxttap', res_graph) # dynamically listen to right clicks

display(cytoscapeobj) # display the object
display(out) # display the output
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'circle'}, cytoscape_style=[{'selector': 'node', 'style': {'font-fam…
# Output()

# %%
cytoscapeobj.get_style()
# Out:
# [{'selector': 'node[id = "Type of Project"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Project',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Type of Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Preregistration',
#    'shape': 'diamond'}},
#  {'selector': 'node[id = "Type of Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "OSF Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'OSF Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "AsPredicted Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'AsPredicted Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "Journal"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Journal',
#    'shape': 'circle'}},
#  {'selector': 'node[id = ""]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': '',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Type of Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "OSF Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'OSF Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "AsPredicted Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'AsPredicted Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "Journal"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Journal',
#    'shape': 'circle'}},
#  {'selector': 'node[id = ""]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': '',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Type of Project"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Project',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Type of Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Preregistration',
#    'shape': 'diamond'}},
#  {'selector': 'node[id = "Type of Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Preregistration Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Preregistration Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "Registered Report Framework"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Registered Report Framework',
#    'shape': 'rectangle'}},
#  {'selector': 'node[id = "OSF Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'OSF Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "AsPredicted Templates"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'AsPredicted Templates',
#    'shape': 'circle'}},
#  {'selector': 'node[id = "Journal"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Journal',
#    'shape': 'circle'}},
#  {'selector': 'node[id = ""]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': '',
#    'shape': 'rectangle'}}]

# %%
{'selector': 'node[id = \"{node["id"]}\"]'}
# Out:
# {'selector': 'node[id = "{node["id"]}"]'}
