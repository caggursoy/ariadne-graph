# %%
# Prerequisites, just run this
import networkx as nx
import pandas as pd
import json
from ipycytoscape import *
df = pd.read_csv('data_materialcheck.csv', sep=';')

# %%
# Also this
df = df.fillna('')
df
# Out:
#     id   type                         label      shape fillcolor fontcolor  \
# 0    1  lower                 Project Start  rectangle    Purple     white
# 1    2  lower               Type of Project    diamond   Thistle     white
# 2    3  lower                 Type of Study    diamond   Thistle     white
# 3    4  lower             Data Availability    diamond   Thistle     white
# 4    5  lower               Data Simulation    diamond   Thistle     white
# 5    6  lower             Experiment Design  rectangle    Purple     white
# 6    7  lower               Data Collection  rectangle    Purple     white
# 7    8  lower               Data Validation  rectangle    Purple     white
# 8    9  lower                 Data Analysis  rectangle    Purple     white
# 9   10  lower                       Writing  rectangle    Purple     white
# 10  11  lower                 Dissemination  rectangle    Purple     white
# 11  12  lower                   Project End  rectangle    Purple     white
# 12  14  lower       Type of Preregistration    diamond      Cyan     white
# 13  15  lower  Preregistration Metaanalysis    diamond      Cyan     white
# 14  16  lower              Design Framework    diamond      Cyan     white
# 15  17  lower                   Sample Size    diamond      Cyan     white
# 16  18  lower                       Stimuli    diamond      Cyan     white
# 17  19  lower                     Open Code    diamond      Cyan     white
# 18  20  lower                Open Materials    diamond      Cyan     white
# 19  21  lower                     Open Data    diamond      Cyan     white
# 20  22  lower                  Presentation    diamond      Cyan     white
# 21  23  lower       Type of Preregistration    diamond      Cyan     white
# 22  24  lower               Preregistration    diamond   #9acd32     black
# 23  25  lower     Preregistration Framework    diamond   #63b8ff     black
# 24  26  lower             Registered Report    diamond   #9acd32     black
# 25  27  lower                 OSF Templates    ellipse   #cd6889     black
# 26  28  lower         AsPredicted Templates    ellipse   #cd6889     black
# 27  29  lower   Registered Report Framework    diamond   #63b8ff     black
# 28  30  lower                       Journal    ellipse   #cd6889     black
#
#     rank               subgraph              connection_from  \
# 0      1                initial                Project Start
# 1      1                initial              Type of Project
# 2      1                initial                Type of Study
# 3      1                initial            Data Availability
# 4      1                initial              Data Simulation
# 5      1                initial            Experiment Design
# 6      1                initial              Data Collection
# 7      1                initial              Data Validation
# 8      1                initial                Data Analysis
# 9      1                initial                      Writing
# 10     1                initial                Dissemination
# 11     1                initial
# 12     2          TypeofProject              Type of Project
# 13     2            TypeofStudy                Type of Study
# 14     2       ExperimentDesign            Experiment Design
# 15     2       ExperimentDesign            Experiment Design
# 16     2       ExperimentDesign            Experiment Design
# 17     2          Dissemination                Dissemination
# 18     2          Dissemination                Dissemination
# 19     2          Dissemination                Dissemination
# 20     2          Dissemination                Dissemination
# 21     2  TypeofPreregistration      Type of Preregistration
# 22     3  TypeofPreregistration              Preregistration
# 23     4  TypeofPreregistration      Type of Preregistration
# 24     3  TypeofPreregistration            Registered Report
# 25     5  TypeofPreregistration    Preregistration Framework
# 26     5  TypeofPreregistration    Preregistration Framework
# 27     4  TypeofPreregistration  Registered Report Framework
# 28     5  TypeofPreregistration
#
#                    connection_to              edgeLabel
# 0                Type of Project
# 1                  Type of Study  Continue after choice
# 2              Data Availability               Empircal
# 3                Data Simulation
# 4              Experiment Design
# 5                Data Collection
# 6                Data Validation
# 7                  Data Analysis
# 8                        Writing
# 9                  Dissemination
# 10                   Project End
# 11
# 12       Type of Preregistration
# 13  Preregistration Metaanalysis
# 14              Design Framework
# 15                   Sample Size
# 16                       Stimuli
# 17                     Open Code
# 18                Open Materials
# 19                     Open Data
# 20                  Presentation
# 21               Preregistration
# 22     Preregistration Framework
# 23             Registered Report
# 24   Registered Report Framework
# 25                 OSF Templates
# 26         AsPredicted Templates
# 27                       Journal
# 28

# %%
# Import stuff to dynamically update the graph
from ipywidgets import Output
from IPython.display import display

# instantiate an jupyternotebook output
out = Output()
# style
fin_style = []
# define a function that draws the network wrt a selected node
def draw_net(node_filter): 
    base_graph = nx.Graph() # reset the network obj
    for index, row in df.iterrows(): # iterate the dataframe
        if row['subgraph'] == node_filter.replace(' ',''): # if the clicked node has a subgraph
            base_graph.add_node(row['connection_to']) # add node
            base_graph.add_node(row['connection_from']) # add node
            base_graph.add_edge(row['connection_to'], row['connection_from']) # now connect the nodes
            rank = row['rank'] # also use rank as output
            subgraph = row['subgraph'] # also use subgraph as output
        elif row['label'] == node_filter: # if the clicked node does not have a subgraph, but it is alone
            base_graph.add_node(row['label']) # just draw the node on its own
            rank = row['rank'] # also use rank as output
            subgraph = row['subgraph'] # also use subgraph as output
    return [base_graph,rank,subgraph] # return the drawn graph
# define a function that logs mouse clicks
def log_clicks(node):
    # style
    fin_style = []
    with out: # while the graph is drawn
        [net,rank,subgraph] = draw_net(node['data']['id']) # draw the network
        cytoscapeobj.graph.clear() # reset cytoscape object
        cytoscapeobj.graph.add_graph_from_networkx(net, directed=True) # now convert the network to a cytoscape object
        cytoscapeobj.set_layout(name = 'dagre')  # it is hierarchical, so show it like that!
        for node in net.nodes: # now iterate the nodes
            shape = df[df.eval("(label == \""+node+"\") & ("+"subgraph == \""+subgraph+"\") & (rank == "+str(rank)+")")]['shape'].values # get the shape by filtering the dataframe
            fillcolor = df[df.eval("(label == \""+node+"\")")]['fillcolor'].values
            if len(shape) == 0: # if not found, i.e. 0th level node
                shape = ['rectangle'] # draw as rectangle
            if len(fillcolor) == 0:
                fillcolor = ['Gray']
            node_dict = {'selector': f'node[id = \"{node}\"]'} # get node id in cyto logic
            style_dict = {"style": {'font-family': 'helvetica',
                                    'font-size': '20px',
                                    'label': node, 
                                    'shape': shape[0],
                                    'background-color': fillcolor[0]
                                   }} # put node id and shape in cyto logic
            node_dict.update(style_dict) # update dict
            fin_style.append(node_dict) # append to style list
        cytoscapeobj.set_style(fin_style) # now set the final style
        
# just initialise the 0th level graph
def init_graph():
    base_graph = nx.Graph() # reset the network obj
    fin_style = []
    for index, row in df.iterrows(): # iterate the dataframe
        if row['subgraph'] == 'initial' and row['rank'] == 1: # only draw the initial and 0th level nodes
            base_graph.add_edge(row['connection_to'], row['connection_from']) # add the edges, nodes should be added automatically
            node = row['label']
            node_dict = {'selector': f'node[id = \"{node}\"]'} # get node id in cyto logic
            style_dict = {"style": {'font-family': 'helvetica',
                                    'font-size': '20px',
                                    'label': row['label'], 
                                    'shape': row['shape'],
                                    'background-color': row['fillcolor']
                                   }} # put node id and shape in cyto logic
            node_dict.update(style_dict) # update dict
            fin_style.append(node_dict) # append to style list
    cytoscapeobj.graph.clear() # reset cytoscape object
    cytoscapeobj.graph.add_graph_from_networkx(base_graph, directed=True) # now convert the network to a cytoscape object
    cytoscapeobj.set_layout(name = 'circle') # show it in a circular fashion
    cytoscapeobj.set_style(fin_style) # set the style
    
# reset the graph
def res_graph(node):
    with out: # reset the DRAWN graph
        base_graph = nx.Graph() # reset the network obj
        fin_style = []
        for index, row in df.iterrows(): # iterate the dataframe
            if row['subgraph'] == 'initial' and row['rank'] == 1: # only draw the initial and 0th level nodes 
                base_graph.add_edge(row['connection_to'], row['connection_from']) # add the edges, nodes should be added automatically
                node = row['label']
                node_dict = {'selector': f'node[id = \"{node}\"]'} # get node id in cyto logic
                style_dict = {"style": {'font-family': 'helvetica',
                                        'font-size': '20px',
                                        'label': row['label'], 
                                        'shape': row['shape'],
                                        'background-color': row['fillcolor']
                                       }} # put node id and shape in cyto logic
                node_dict.update(style_dict) # update dict
                fin_style.append(node_dict) # append to style list
        cytoscapeobj.graph.clear() # reset cytoscape object
        cytoscapeobj.graph.add_graph_from_networkx(base_graph, directed=True) # now convert the network to a cytoscape object
        cytoscapeobj.set_layout(name = 'circle') # show it in a circular fashion
        cytoscapeobj.set_style(fin_style) # set the style
    
cytoscapeobj = CytoscapeWidget() # ok now create the cytoscape object
my_style = [ # a variable for our initial style
    {'selector': 'node','style': {
        'font-family': 'helvetica',
        'font-size': '20px',
        'label': 'data(id)', 
        'shape':'rectangle'}},
    ]
init_graph() # init the network graph
#cytoscapeobj.set_style(my_style) # set the style
#
cytoscapeobj.on('node', 'click', log_clicks) # dynamically listen to left clicks
cytoscapeobj.on('node', 'cxttap', res_graph) # dynamically listen to right clicks
display(cytoscapeobj) # display the object
display(out) # display the output
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'circle'}, cytoscape_style=[{'selector': 'node[id = "Project Start"]…
# Output()

# %%
cytoscapeobj.get_style()
# Out:
# [{'selector': 'node[id = "Project Start"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Project Start',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Type of Project"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Project',
#    'shape': 'diamond',
#    'background-color': 'Thistle'}},
#  {'selector': 'node[id = "Type of Study"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Type of Study',
#    'shape': 'diamond',
#    'background-color': 'Thistle'}},
#  {'selector': 'node[id = "Data Availability"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Data Availability',
#    'shape': 'diamond',
#    'background-color': 'Thistle'}},
#  {'selector': 'node[id = "Data Simulation"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Data Simulation',
#    'shape': 'diamond',
#    'background-color': 'Thistle'}},
#  {'selector': 'node[id = "Experiment Design"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Experiment Design',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Data Collection"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Data Collection',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Data Validation"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Data Validation',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Data Analysis"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Data Analysis',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Writing"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Writing',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Dissemination"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Dissemination',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}},
#  {'selector': 'node[id = "Project End"]',
#   'style': {'font-family': 'helvetica',
#    'font-size': '20px',
#    'label': 'Project End',
#    'shape': 'rectangle',
#    'background-color': 'Purple'}}]

# %%
{'selector': 'node[id = \"{node["id"]}\"]'}
# Out:
# {'selector': 'node[id = "{node["id"]}"]'}

# %%
id = 0
for edge in cytoscapeobj.graph.edges:
    edge.data['id'] = df['edgeLabel'][id]
    id += 1
